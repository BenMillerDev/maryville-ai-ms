# %% [markdown]
# ## DSCI 503 - Homework 00
#
# **Ben Miller**
#
# Due Wednesday, 08/27

# %% [markdown]
# ### Part 1: Arithmetic Operations
#
# In this section of the assignment, we will demonstrate the following concepts:
# * Addition
# * Subtraction
# * Multiplication
# * Division
# * Exponentiation

# %%
print(7 + 2)
# Out:
# 9

# %%
print(7 - 2)
# Out:
# 5

# %%
print(7 * 2)
# Out:
# 14

# %%
print(7 / 2)
# Out:
# 3.5

# %%
print(7 ** 2)
# Out:
# 49

# %% [markdown]
# ### Part 2: Variables
#
# In this section of the assignment, we will demonstrate the following concepts:
# * Creating variables.
# * Printing the value of variables.
# * Operations with variables.
# * Nonlinear execution in notebooks.

# %%
x = 91

# %%
x = 42

# %%
print(x)
# Out:
# 42

# %%
y = 7

# %%
print(y)
# Out:
# 7

# %%
print(x / y)
# Out:
# 6.0

# %% [markdown]
# ### Part 3: Comments
# In this section of the assignment, we will demonstrate the following concepts:
#
# * Writing comments
# * Using comments to document code
# * Using comments to disable lines of code

# %%
# This is a comment
print(2 + 5)
# Out:
# 7

# %%
# In this cell, we will calculate sales revenue.
sales = 173               # Monthly widget sales
price = 16.98             # Price per widget
revenue = sales * price   # Monthly reveneue
print(revenue)
# Out:
# 2937.54

# %%
print(12 / 6)
# print(12 / 0)
print(12 / 4)
# Out:
# 2.0
# 3.0

# %% [markdown]
# ### Part 4: Strings
# In this section of the assignment, we will demonstrate the following concepts:
# * Creating strings
# * Storing strings in variables
# * Printing multiple items

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
name = "Ben Miller"
print(name)
# Out:
# Ben Miller

# %%
print("Hello, my name is", name)
# Out:
# Hello, my name is Ben Miller

# %%
print("Hello, my name is ", name, ".", sep="")
# Out:
# Hello, my name is Ben Miller.
